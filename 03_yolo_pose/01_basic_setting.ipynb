# %% [markdown]
# ### Yolo v8 Pose
# - 모든 모델은 첫번째 사용시 자동으로 다운로드
# - YOLOv8n-pose를 일반적으로 사용
# - COCO Keypoints val2017 dataset
#     - yolo val pose data=coco-pose.yaml device=0
#     - yolo val pose data=coco8-pose.yaml batch=1 device=0|cpu

# %%
from ultralytics import YOLO

model = YOLO('yolov8m-pose.pt')

results = model(source="./son_01.mp4", show=True, conf=0.3, save=True)
# Out:
# ...
# 100%|██████████| 50.8M/50.8M [01:02<00:00, 855kB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/255) d:\Github\Vision_WS\Yolo_Basic\03_yolo_pose\son_01.mp4: 384x640 4 persons, 881.6ms
# video 1/1 (2/255) d:\Github\Vision_WS\Yolo_Basic\03_yolo_pose\son_01.mp4: 384x640 4 persons, 532.0ms
# video 1/1 (3/255) d:\Github\Vision_WS\Yolo_Basic\03_yolo_pose\son_01.mp4: 384x640 4 persons, 511.0ms
# ...
